# %% [markdown]
# <a href="https://colab.research.google.com/github/BiggusMaximus/Tensorflow_Certification_Preparation_Dicoding/blob/main/C4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =====================================================================================================
# PROBLEM C4
#
# Build and train a classifier for the sarcasm dataset.
# The classifier should have a final layer with 1 neuron activated by sigmoid.
#
# Do not use lambda layers in your model.
#
# Dataset used in this problem is built by Rishabh Misra (https://rishabhmisra.github.io/publications).
#
# Desired accuracy and validation_accuracy > 75%
# =======================================================================================================

import json
import tensorflow as tf
import numpy as np
import urllib
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request

def solution_C4():
    data_url = 'https://github.com/dicodingacademy/assets/raw/main/Simulation/machine_learning/sarcasm.json'
    urllib.request.urlretrieve(data_url, 'sarcasm.json')
    with open("sarcasm.json", 'r') as f:
      datastore = json.load(f)
  
    # DO NOT CHANGE THIS CODE
    # Make sure you used all of these parameters or test may fail
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type = 'post'
    padding_type = 'post'
    oov_tok = "<OOV>"
    training_size = 20000

    sentences = []
    labels = []
    # YOUR CODE HERE
    for item in datastore:
      sentences.append(item['headline'])
      labels.append(item['is_sarcastic'])

    training_sentences  = sentences[0:training_size]
    testing_sentences   = sentences[training_size:]
    training_labels     = labels[0:training_size]
    testing_labels      = labels[training_size:]
    # Fit your tokenizer with training data
    tokenizer           =  Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(training_sentences)

    word_index          = tokenizer.word_index
    training_sequences  = tokenizer.texts_to_sequences(training_sentences)
    training_padded     = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
    testing_sequences   = tokenizer.texts_to_sequences(testing_sentences)
    testing_padded      = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
        tf.keras.layers.Dense(24, activation='relu'),
        # YOUR CODE HERE. DO not change the last layer or test may fail
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
    num_epochs = 50
    training_padded = np.array(training_padded)
    training_labels = np.array(training_labels)
    testing_padded = np.array(testing_padded)
    testing_labels = np.array(testing_labels)
    model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1)
    return model


# The code below is to save your model as a .h5 file.
# It will be saved automatically in your Submission folder.
if __name__ == '__main__':
    # DO NOT CHANGE THIS CODE
    model = solution_C4()
    model.save("model_C4.h5")
# Out:
# Epoch 1/50
# 625/625 [==============================] - 47s 70ms/step - loss: 0.4596 - accuracy: 0.7707 - val_loss: 0.3826 - val_accuracy: 0.8267
# Epoch 2/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.3461 - accuracy: 0.8429 - val_loss: 0.3714 - val_accuracy: 0.8275
# Epoch 3/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.3260 - accuracy: 0.8536 - val_loss: 0.3717 - val_accuracy: 0.8286
# Epoch 4/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.3096 - accuracy: 0.8628 - val_loss: 0.3704 - val_accuracy: 0.8340
# Epoch 5/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.2995 - accuracy: 0.8676 - val_loss: 0.3727 - val_accuracy: 0.8316
# Epoch 6/50
# 625/625 [==============================] - 40s 65ms/step - loss: 0.2907 - accuracy: 0.8725 - val_loss: 0.3781 - val_accuracy: 0.8293
# Epoch 7/50
# 625/625 [==============================] - 40s 63ms/step - loss: 0.2826 - accuracy: 0.8769 - val_loss: 0.3871 - val_accuracy: 0.8269
# Epoch 8/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.2745 - accuracy: 0.8799 - val_loss: 0.3846 - val_accuracy: 0.8262
# Epoch 9/50
# 625/625 [==============================] - 40s 65ms/step - loss: 0.2661 - accuracy: 0.8842 - val_loss: 0.3975 - val_accuracy: 0.8296
# Epoch 10/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.2590 - accuracy: 0.8889 - val_loss: 0.4021 - val_accuracy: 0.8283
# Epoch 11/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.2525 - accuracy: 0.8914 - val_loss: 0.4115 - val_accuracy: 0.8267
# Epoch 12/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.2439 - accuracy: 0.8942 - val_loss: 0.4400 - val_accuracy: 0.8208
# Epoch 13/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.2373 - accuracy: 0.8981 - val_loss: 0.4081 - val_accuracy: 0.8268
# Epoch 14/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.2292 - accuracy: 0.9015 - val_loss: 0.4868 - val_accuracy: 0.8220
# Epoch 15/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.2232 - accuracy: 0.9036 - val_loss: 0.4433 - val_accuracy: 0.8225
# Epoch 16/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.2155 - accuracy: 0.9089 - val_loss: 0.4593 - val_accuracy: 0.8235
# Epoch 17/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.2099 - accuracy: 0.9115 - val_loss: 0.4668 - val_accuracy: 0.8204
# Epoch 18/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1994 - accuracy: 0.9161 - val_loss: 0.5265 - val_accuracy: 0.8190
# Epoch 19/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.1951 - accuracy: 0.9173 - val_loss: 0.5038 - val_accuracy: 0.8208
# Epoch 20/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1878 - accuracy: 0.9218 - val_loss: 0.5326 - val_accuracy: 0.8205
# Epoch 21/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.1818 - accuracy: 0.9248 - val_loss: 0.5595 - val_accuracy: 0.8089
# Epoch 22/50
# 625/625 [==============================] - 42s 66ms/step - loss: 0.1735 - accuracy: 0.9273 - val_loss: 0.6383 - val_accuracy: 0.8158
# Epoch 23/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1667 - accuracy: 0.9308 - val_loss: 0.6541 - val_accuracy: 0.8144
# Epoch 24/50
# 625/625 [==============================] - 43s 69ms/step - loss: 0.1619 - accuracy: 0.9330 - val_loss: 0.6476 - val_accuracy: 0.8117
# Epoch 25/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1540 - accuracy: 0.9376 - val_loss: 0.6941 - val_accuracy: 0.8068
# Epoch 26/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.1469 - accuracy: 0.9403 - val_loss: 0.7261 - val_accuracy: 0.8055
# Epoch 27/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.1440 - accuracy: 0.9411 - val_loss: 0.7276 - val_accuracy: 0.8073
# Epoch 28/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1341 - accuracy: 0.9458 - val_loss: 0.7540 - val_accuracy: 0.8058
# Epoch 29/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.1304 - accuracy: 0.9467 - val_loss: 0.7685 - val_accuracy: 0.8088
# Epoch 30/50
# 625/625 [==============================] - 42s 68ms/step - loss: 0.1255 - accuracy: 0.9492 - val_loss: 0.8070 - val_accuracy: 0.8032
# Epoch 31/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1182 - accuracy: 0.9510 - val_loss: 0.8728 - val_accuracy: 0.8027
# Epoch 32/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.1112 - accuracy: 0.9550 - val_loss: 0.9661 - val_accuracy: 0.8025
# Epoch 33/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.1103 - accuracy: 0.9551 - val_loss: 0.9169 - val_accuracy: 0.7998
# Epoch 34/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.1028 - accuracy: 0.9579 - val_loss: 1.0314 - val_accuracy: 0.8064
# Epoch 35/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.0968 - accuracy: 0.9610 - val_loss: 1.0467 - val_accuracy: 0.8007
# Epoch 36/50
# 625/625 [==============================] - 43s 68ms/step - loss: 0.0920 - accuracy: 0.9624 - val_loss: 1.1535 - val_accuracy: 0.8027
# Epoch 37/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0916 - accuracy: 0.9625 - val_loss: 1.1122 - val_accuracy: 0.8019
# Epoch 38/50
# 625/625 [==============================] - 43s 70ms/step - loss: 0.0872 - accuracy: 0.9648 - val_loss: 1.1304 - val_accuracy: 0.7974
# Epoch 39/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.0814 - accuracy: 0.9671 - val_loss: 1.1841 - val_accuracy: 0.7997
# Epoch 40/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.0790 - accuracy: 0.9689 - val_loss: 1.1915 - val_accuracy: 0.7974
# Epoch 41/50
# 625/625 [==============================] - 42s 67ms/step - loss: 0.0722 - accuracy: 0.9711 - val_loss: 1.3060 - val_accuracy: 0.7980
# Epoch 42/50
# 625/625 [==============================] - 42s 68ms/step - loss: 0.0746 - accuracy: 0.9699 - val_loss: 1.2903 - val_accuracy: 0.7976
# Epoch 43/50
# 625/625 [==============================] - 42s 66ms/step - loss: 0.0730 - accuracy: 0.9716 - val_loss: 1.2824 - val_accuracy: 0.8001
# Epoch 44/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.0635 - accuracy: 0.9734 - val_loss: 1.4149 - val_accuracy: 0.7967
# Epoch 45/50
# 625/625 [==============================] - 42s 68ms/step - loss: 0.0669 - accuracy: 0.9730 - val_loss: 1.3920 - val_accuracy: 0.8007
# Epoch 46/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.0611 - accuracy: 0.9758 - val_loss: 1.4778 - val_accuracy: 0.7970
# Epoch 47/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0576 - accuracy: 0.9768 - val_loss: 1.5027 - val_accuracy: 0.7977
# Epoch 48/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0564 - accuracy: 0.9762 - val_loss: 1.5904 - val_accuracy: 0.7904
# Epoch 49/50
# 625/625 [==============================] - 41s 66ms/step - loss: 0.0511 - accuracy: 0.9790 - val_loss: 1.7010 - val_accuracy: 0.7916
# Epoch 50/50
# 625/625 [==============================] - 41s 65ms/step - loss: 0.0533 - accuracy: 0.9790 - val_loss: 1.6764 - val_accuracy: 0.7891
